# %%
try:
    a=int(input("enter an number:"))
except:
    print(int(input("enter an valid input")))
print(f"multiplication table of {a} is:")
for i in range(1,11):
    n=i*a
    print(f"{i}x{a}={n}")
# Out:
# enter an number: df
# enter an valid input 2
# 2
# multiplication table of 2 is:
# 1x2=2
# 2x2=4
# 3x2=6
# 4x2=8
# 5x2=10
# 6x2=12
# 7x2=14
# 8x2=16
# 9x2=18
# 10x2=20
