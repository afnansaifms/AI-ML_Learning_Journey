# %%
import re

# %%
text="""On 12/05/2025, John Doe (john.doe@gmail.com) placed Order #12345 worth $149.99.
His backup email was john_doe123@outlook.com, and his phone numbers were +91 9876543210 and 98765-43210.
The order was shipped on 2025-05-14 with Tracking ID TRK-AB1234-XZ. Another customer, 
Alice Smith, can be reached at alice.smith@yahoo.in or +1-555-123-4567. 
Visit https://example.com/orders/12345 or http://shop.test.org for details.
Invalid entries include hello@.com, 123456789, and 31/13/2024. Employee IDs EMP001, EMP245, and EMP999 processed the requests.
Products purchased were Book-101, Laptop-202, and Mouse-303. The meeting is scheduled for Feb 14, 2026 at 09:30 AM in Room-A12.
Pot Hot"""

# %%
pattern="was"
match=re.search(pattern,text)
print(match)
# Out:
# <re.Match object; span=(97, 100), match='was'>

# %%
pattern=r"[A-Z]is"
match=re.search(pattern,text)
print(match)
# Out:
# <re.Match object; span=(80, 83), match='His'>

# %%
pattern=r"[A-Z]ot"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(676, 679), match='Pot'>
# <re.Match object; span=(680, 683), match='Hot'>

# %%
pattern="[a-z0-9._%+-]+@[a-z0-9.-]+[a-z]{2,}"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(25, 43), match='john.doe@gmail.com'>
# <re.Match object; span=(101, 124), match='john_doe123@outlook.com'>
# <re.Match object; span=(303, 323), match='alice.smith@yahoo.in'>
# <re.Match object; span=(445, 455), match='hello@.com'>

# %%
pattern="\d{2}/\d{2}/\d{4}"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(3, 13), match='12/05/2025'>
# <re.Match object; span=(472, 482), match='31/13/2024'>
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\adnan\AppData\Local\Temp\ipykernel_32732\513736361.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern="\d{2}/\d{2}/\d{4}"

# %%
print(text[0:20])
# Out:
# On 12/05/2025, John

# %%
pattern="[a-z0-9._%+-]+@[a-z0-9.-]+[a-z]{2,}"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(359, 370), match='example.com'>

# %%
pattern=r"\d"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(3, 4), match='1'>
# <re.Match object; span=(4, 5), match='2'>
# <re.Match object; span=(6, 7), match='0'>
# <re.Match object; span=(7, 8), match='5'>
# <re.Match object; span=(9, 10), match='2'>
# <re.Match object; span=(10, 11), match='0'>
# <re.Match object; span=(11, 12), match='2'>
# <re.Match object; span=(12, 13), match='5'>
# <re.Match object; span=(59, 60), match='1'>
# <re.Match object; span=(60, 61), match='2'>
# <re.Match object; span=(61, 62), match='3'>
# <re.Match object; span=(62, 63), match='4'>
# <re.Match object; span=(63, 64), match='5'>
# <re.Match object; span=(72, 73), match='1'>
# <re.Match object; span=(73, 74), match='4'>
# <re.Match object; span=(74, 75), match='9'>
# <re.Match object; span=(76, 77), match='9'>
# <re.Match object; span=(77, 78), match='9'>
# <re.Match object; span=(109, 110), match='1'>
# <re.Match object; span=(110, 111), match='2'>
# <re.Match object; span=(111, 112), match='3'>
# ...

# %%
pattern=r"\D"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 1), match='O'>
# <re.Match object; span=(1, 2), match='n'>
# <re.Match object; span=(2, 3), match=' '>
# <re.Match object; span=(5, 6), match='/'>
# <re.Match object; span=(8, 9), match='/'>
# <re.Match object; span=(13, 14), match=','>
# <re.Match object; span=(14, 15), match=' '>
# <re.Match object; span=(15, 16), match='J'>
# <re.Match object; span=(16, 17), match='o'>
# <re.Match object; span=(17, 18), match='h'>
# <re.Match object; span=(18, 19), match='n'>
# <re.Match object; span=(19, 20), match=' '>
# <re.Match object; span=(20, 21), match='D'>
# <re.Match object; span=(21, 22), match='o'>
# <re.Match object; span=(22, 23), match='e'>
# <re.Match object; span=(23, 24), match=' '>
# <re.Match object; span=(24, 25), match='('>
# <re.Match object; span=(25, 26), match='j'>
# <re.Match object; span=(26, 27), match='o'>
# <re.Match object; span=(27, 28), match='h'>
# <re.Match object; span=(28, 29), match='n'>
# ...

# %%
pattern=r"\w"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 1), match='O'>
# <re.Match object; span=(1, 2), match='n'>
# <re.Match object; span=(3, 4), match='1'>
# <re.Match object; span=(4, 5), match='2'>
# <re.Match object; span=(6, 7), match='0'>
# <re.Match object; span=(7, 8), match='5'>
# <re.Match object; span=(9, 10), match='2'>
# <re.Match object; span=(10, 11), match='0'>
# <re.Match object; span=(11, 12), match='2'>
# <re.Match object; span=(12, 13), match='5'>
# <re.Match object; span=(15, 16), match='J'>
# <re.Match object; span=(16, 17), match='o'>
# <re.Match object; span=(17, 18), match='h'>
# <re.Match object; span=(18, 19), match='n'>
# <re.Match object; span=(20, 21), match='D'>
# <re.Match object; span=(21, 22), match='o'>
# <re.Match object; span=(22, 23), match='e'>
# <re.Match object; span=(25, 26), match='j'>
# <re.Match object; span=(26, 27), match='o'>
# <re.Match object; span=(27, 28), match='h'>
# <re.Match object; span=(28, 29), match='n'>
# <re.Match object; span=(30, 31), match='d'>
# ...

# %%
pattern=r"\W"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(2, 3), match=' '>
# <re.Match object; span=(5, 6), match='/'>
# <re.Match object; span=(8, 9), match='/'>
# <re.Match object; span=(13, 14), match=','>
# <re.Match object; span=(14, 15), match=' '>
# <re.Match object; span=(19, 20), match=' '>
# <re.Match object; span=(23, 24), match=' '>
# <re.Match object; span=(24, 25), match='('>
# <re.Match object; span=(29, 30), match='.'>
# <re.Match object; span=(33, 34), match='@'>
# <re.Match object; span=(39, 40), match='.'>
# <re.Match object; span=(43, 44), match=')'>
# <re.Match object; span=(44, 45), match=' '>
# <re.Match object; span=(51, 52), match=' '>
# <re.Match object; span=(57, 58), match=' '>
# <re.Match object; span=(58, 59), match='#'>
# <re.Match object; span=(64, 65), match=' '>
# <re.Match object; span=(70, 71), match=' '>
# <re.Match object; span=(71, 72), match='$'>
# <re.Match object; span=(75, 76), match='.'>
# <re.Match object; span=(78, 79), match='.'>
# ...

# %%
pattern=r"\s"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(2, 3), match=' '>
# <re.Match object; span=(14, 15), match=' '>
# <re.Match object; span=(19, 20), match=' '>
# <re.Match object; span=(23, 24), match=' '>
# <re.Match object; span=(44, 45), match=' '>
# <re.Match object; span=(51, 52), match=' '>
# <re.Match object; span=(57, 58), match=' '>
# <re.Match object; span=(64, 65), match=' '>
# <re.Match object; span=(70, 71), match=' '>
# <re.Match object; span=(79, 80), match='\n'>
# <re.Match object; span=(83, 84), match=' '>
# <re.Match object; span=(90, 91), match=' '>
# <re.Match object; span=(96, 97), match=' '>
# <re.Match object; span=(100, 101), match=' '>
# <re.Match object; span=(125, 126), match=' '>
# <re.Match object; span=(129, 130), match=' '>
# <re.Match object; span=(133, 134), match=' '>
# <re.Match object; span=(139, 140), match=' '>
# <re.Match object; span=(147, 148), match=' '>
# <re.Match object; span=(152, 153), match=' '>
# <re.Match object; span=(156, 157), match=' '>
# ...

# %%
pattern=r"\S"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 1), match='O'>
# <re.Match object; span=(1, 2), match='n'>
# <re.Match object; span=(3, 4), match='1'>
# <re.Match object; span=(4, 5), match='2'>
# <re.Match object; span=(5, 6), match='/'>
# <re.Match object; span=(6, 7), match='0'>
# <re.Match object; span=(7, 8), match='5'>
# <re.Match object; span=(8, 9), match='/'>
# <re.Match object; span=(9, 10), match='2'>
# <re.Match object; span=(10, 11), match='0'>
# <re.Match object; span=(11, 12), match='2'>
# <re.Match object; span=(12, 13), match='5'>
# <re.Match object; span=(13, 14), match=','>
# <re.Match object; span=(15, 16), match='J'>
# <re.Match object; span=(16, 17), match='o'>
# <re.Match object; span=(17, 18), match='h'>
# <re.Match object; span=(18, 19), match='n'>
# <re.Match object; span=(20, 21), match='D'>
# <re.Match object; span=(21, 22), match='o'>
# <re.Match object; span=(22, 23), match='e'>
# <re.Match object; span=(24, 25), match='('>
# <re.Match object; span=(25, 26), match='j'>
# ...

# %%
pattern=r"\bcom"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(40, 43), match='com'>
# <re.Match object; span=(121, 124), match='com'>
# <re.Match object; span=(367, 370), match='com'>
# <re.Match object; span=(452, 455), match='com'>

# %%
pattern=r"^On"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 2), match='On'>

# %%
pattern=r"Hot$"
matches=re.finditer(pattern,text)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(680, 683), match='Hot'>

# %%
with open("file.txt",'r') as f:
    content=f.read()
    pattern=r"\d\d\d.\d\d\d.\d\d\d"
    match=re.finditer(pattern,test)
    for i in match:
        print(i)
# Out:
# <re.Match object; span=(311, 322), match='321-244-333'>
# <re.Match object; span=(571, 582), match='022-2456789'>
# <re.Match object; span=(640, 651), match='555-123-456'>

# %%
pattern=r"\d{3}.\d{3}.\d{3}"
match=re.finditer(pattern,test)
for i in match:
    print(i)
# Out:
# <re.Match object; span=(311, 322), match='321-244-333'>
# <re.Match object; span=(571, 582), match='022-2456789'>
# <re.Match object; span=(640, 651), match='555-123-456'>

# %%
pattern=r"\+\d{2}-\d{10}"
match=re.finditer(pattern,test)
for i in match:
    print(i)
# Out:
# <re.Match object; span=(172, 186), match='+91-9988776655'>
